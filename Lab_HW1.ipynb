# %% [markdown]
# فراخوانی ماژول‌های
# - `matplotlib` برای تصویر سازی داده
# - `pandas` برای کار با داده‌های جدولی
# - `numpy` برای انجام عملیات آرایه‌ای

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
from IPython.core.display import HTML
HTML("<style>.jp-RenderedMarkdown{font-family:'IRANSans,Tahoma,Helvetica,sans-serif';display:flex;flex-direction:column;margin-top:10px;font-size:1rem;direction:rtl}mark{color:inherit;padding:2px; background-color:#88888888}</style>")
# Out:
# <style>.jp-RenderedMarkdown{font-family:'IRANSans,Tahoma,Helvetica,sans-serif';display:flex;flex-direction:column;margin-top:10px;font-size:1rem;direction:rtl}mark{color:inherit;padding:2px; background-color:#88888888}</style>

# %% [markdown]
# فراخوانی داده‌ها با پانداس.

# %%
df = pd.read_csv('LaLiga_dataset.csv')
df
# Out:
#       season                club  home_win  away_win  home_loss  away_loss  \
# 0    1970-71       Real Zaragoza         3         0          5         13
# 1    1970-71               Elche         4         0          5         11
# 2    1970-71          Las Palmas         5         0          3         12
# 3    1970-71            Sabadell         8         0          3         14
# 4    1970-71            Espanyol         7         1          4          9
# ..       ...                 ...       ...       ...        ...        ...
# 903  2016-17          Villarreal        11         8          4          5
# 904  2016-17             Sevilla        14         7          1          7
# 905  2016-17  Atletico de Madrid        14         9          3          3
# 906  2016-17           Barcelona        15        13          1          3
# 907  2016-17         Real Madrid        14        15          1          2
#
#      matches_won  matches_lost  matches_drawn  total_matches  points  \
# 0              3            18              9             30      18
# 1              4            16             10             30      22
# 2              5            15             10             30      25
# 3              8            17              5             30      29
# 4              8            13              9             30      33
# ..           ...           ...            ...            ...     ...
# 903           19             9             10             38      67
# 904           21             8              9             38      72
# 905           23             6              9             38      78
# 906           28             4              6             38      90
# 907           29             3              6             38      93
#
#      home_goals  away_goals  goals_scored  goals_conceded  goal_difference
# 0            14           8            22              54              -32
# 1            17           8            25              46              -21
# 2            25           8            33              42               -9
# 3            19           9            28              49              -21
# 4            13           5            18              25               -7
# ..          ...         ...           ...             ...              ...
# 903          35          21            56              33               23
# 904          39          30            69              49               20
# 905          40          30            70              27               43
# 906          64          52           116              37               79
# 907          48          58           106              41               65
#
# [908 rows x 16 columns]

# %% [markdown]
# نمایش ۵ سطر اول داده.

# %%
df.head(5)
# Out:
#     season           club  home_win  away_win  home_loss  away_loss  \
# 0  1970-71  Real Zaragoza         3         0          5         13
# 1  1970-71          Elche         4         0          5         11
# 2  1970-71     Las Palmas         5         0          3         12
# 3  1970-71       Sabadell         8         0          3         14
# 4  1970-71       Espanyol         7         1          4          9
#
#    matches_won  matches_lost  matches_drawn  total_matches  points  \
# 0            3            18              9             30      18
# 1            4            16             10             30      22
# 2            5            15             10             30      25
# 3            8            17              5             30      29
# 4            8            13              9             30      33
#
#    home_goals  away_goals  goals_scored  goals_conceded  goal_difference
# 0          14           8            22              54              -32
# 1          17           8            25              46              -21
# 2          25           8            33              42               -9
# 3          19           9            28              49              -21
# 4          13           5            18              25               -7

# %% [markdown]
# نمایش ۷ سطر آخر داده.

# %%
df.tail(7)
# Out:
#       season                club  home_win  away_win  home_loss  away_loss  \
# 901  2016-17       Athletic Club        13         6          2         11
# 902  2016-17       Real Sociedad        10         9          4          8
# 903  2016-17          Villarreal        11         8          4          5
# 904  2016-17             Sevilla        14         7          1          7
# 905  2016-17  Atletico de Madrid        14         9          3          3
# 906  2016-17           Barcelona        15        13          1          3
# 907  2016-17         Real Madrid        14        15          1          2
#
#      matches_won  matches_lost  matches_drawn  total_matches  points  \
# 901           19            13              6             38      63
# 902           19            12              7             38      64
# 903           19             9             10             38      67
# 904           21             8              9             38      72
# 905           23             6              9             38      78
# 906           28             4              6             38      90
# 907           29             3              6             38      93
#
#      home_goals  away_goals  goals_scored  goals_conceded  goal_difference
# 901          36          17            53              43               10
# 902          30          29            59              53                6
# 903          35          21            56              33               23
# 904          39          30            69              49               20
# 905          40          30            70              27               43
# 906          64          52           116              37               79
# 907          48          58           106              41               65

# %% [markdown]
# نمایش نوع ستون داده‌های فراخوانی شده.

# %%
print(df.dtypes)
# Out:
# season             object
# club               object
# home_win            int64
# away_win            int64
# home_loss           int64
# away_loss           int64
# matches_won         int64
# matches_lost        int64
# matches_drawn       int64
# total_matches       int64
# points              int64
# home_goals          int64
# away_goals          int64
# goals_scored        int64
# goals_conceded      int64
# goal_difference     int64
# dtype: object

# %% [markdown]
# نمایش خلاصه‌های آماری ستون‌های عددی در داده.

# %%
print(df.describe())
# Out:
#          home_win    away_win   home_loss   away_loss  matches_won  \
# count  908.000000  908.000000  908.000000  908.000000   908.000000
# mean     9.582599    4.118943    4.118943    9.582599    13.701542
# std      3.107555    2.776725    2.531206    3.092974     4.966050
# min      1.000000    0.000000    0.000000    1.000000     2.000000
# 25%      7.000000    2.000000    2.000000    8.000000    10.000000
# 50%      9.000000    4.000000    4.000000   10.000000    13.000000
# 75%     12.000000    6.000000    6.000000   12.000000    16.000000
# max     19.000000   16.000000   15.000000   18.000000    32.000000
#
#        matches_lost  matches_drawn  total_matches      points  home_goals  \
# count    908.000000     908.000000     908.000000  908.000000  908.000000
# mean      13.701542       9.577093      36.980176   50.681718   29.508811
# std        4.589442       2.986852       2.522150   14.104626    9.757192
# min        1.000000       1.000000      30.000000   13.000000   11.000000
# 25%       11.000000       7.000000      34.000000   42.000000   23.000000
# 50%       14.000000       9.000000      38.000000   48.000000   28.000000
# 75%       17.000000      12.000000      38.000000   59.000000   34.000000
# max       29.000000      18.000000      44.000000  100.000000   78.000000
#
#        away_goals  goals_scored  goals_conceded  goal_difference
# count  908.000000    908.000000      908.000000       908.000000
# mean    18.267621     47.776432       47.776432         0.000000
# std      7.569011     15.593429       11.855507        21.680653
# min      4.000000     15.000000       18.000000       -64.000000
# 25%     13.000000     37.000000       39.000000       -14.000000
# 50%     17.000000     45.000000       47.000000        -3.000000
# 75%     22.000000     54.000000       56.000000        10.250000
# max     58.000000    121.000000       94.000000        89.000000

# %% [markdown]
# انتخاب فصل‌هایی در داده که تعداد تیم‌های برابر داشته اند.
# محاسبه‌ی مقدار امتیازهای هر فصل و ذخیره در آرایه‌ی نامپای.
# محاسبه‌ی دسته‌بندی‌های هیستوگرام بر اساس کل داده‌های مشاهده شده تا هیستوگرام تمامی نمودارهای دسته‌های یکسانی داشته باشند.
# نمایش هیستوگرام امتیاز نهایی تیم‌ها در انتهای دو فصل مختلف.

# %%
def find_consistent_team_seasons(laliga_data):
    
    team_count_per_season = laliga_data.groupby('season')['club'].nunique()
    
    consistent_seasons = team_count_per_season[team_count_per_season == team_count_per_season.shift(1)]
    
    return consistent_seasons

consistent_seasons = find_consistent_team_seasons(df)
print(consistent_seasons)
# Out:
# season
# 1972-73    18
# 1973-74    18
# 1974-75    18
# 1975-76    18
# 1976-77    18
# 1977-78    18
# 1978-79    18
# 1979-80    18
# 1980-81    18
# 1981-82    18
# 1982-83    18
# 1983-84    18
# 1984-85    18
# 1985-86    18
# 1986-87    18
# 1988-89    20
# 1989-90    20
# 1990-91    20
# 1991-92    20
# 1992-93    20
# 1993-94    20
# 1994-95    20
# 1996-97    22
# 1998-99    20
# 1999-00    20
# 2000-01    20
# 2001-02    20
# 2002-03    20
# 2003-04    20
# 2004-05    20
# 2005-06    20
# 2006-07    20
# 2007-08    20
# 2008-09    20
# 2009-10    20
# 2010-11    20
# 2011-12    20
# 2012-13    20
# 2013-14    20
# 2014-15    20
# 2015-16    20
# 2016-17    20
# Name: club, dtype: int64

# %% [markdown]
# #فصل هایی که در آن تیم ها تعداد تیم های برابر داشته اند.
# #۱۹۷۲ تا ۱۹۸۶
# #۸۸ تا ۲۰۱۷ به جز ۹۶

# %% [markdown]
#  دو تابع
# `min_points(df_laliga,season)`
# و
# `max_points(df_laliga,season)`
# را کامل کنید .

# %%
season_points = df.groupby('season')['points'].sum()
points_array = np.array(season_points)

print(points_array)
# Out:
# [ 659  836  828  847  835  847  843  848  843  831  848  862  839  837
#   809  840 1087 1038 1028 1033 1024 1045 1030 1034 1027 1256 1267 1030
#  1043 1028 1041 1039 1035 1045 1040 1035 1042 1053 1057 1045 1061 1046
#  1056 1054 1049 1048 1051]

# %%
def plot_histograms_for_selected_seasons(laliga_data, seasons):
    
    plt.figure(figsize=(18, 6))
    
    min_points = laliga_data['points'].min()
    max_points = laliga_data['points'].max()
    bins = np.arange(min_points, max_points , 10) 
    
    
        
    season_data_1 = laliga_data[laliga_data['season'] == seasons[0]]['points']
    season_data_2 = laliga_data[laliga_data['season'] == seasons[1]]['points']
    # plt.subplot(1, 2, i + 1)
    plt.hist(season_data_1, bins=bins, alpha=0.7, label=f'{seasons[0]}', edgecolor='black', color=['skyblue'])
    plt.hist(season_data_2, bins=bins, alpha=0.7, label=f'{seasons[1]}', edgecolor='black', color=['salmon'])
    plt.xlabel('Points')
    plt.ylabel('Number of Teams')
    plt.title(f'Histogram of Points: {seasons}')
    #plt.xticks(bins)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()
    
seasons = ['2000-01', '2001-02']
plot_histograms_for_selected_seasons(df, seasons)   
seasons = ['2002-03', '2003-04']
plot_histograms_for_selected_seasons(df, seasons) 
seasons = ['2004-05', '2005-06']
plot_histograms_for_selected_seasons(df, seasons) 
seasons = ['2006-07', '2007-08']
plot_histograms_for_selected_seasons(df, seasons) 
seasons = ['2008-09', '2009-10']
plot_histograms_for_selected_seasons(df, seasons) 
seasons = ['2010-11', '2011-12']
plot_histograms_for_selected_seasons(df, seasons) 
seasons = ['2012-13', '2013-14']
plot_histograms_for_selected_seasons(df, seasons) 
seasons = ['2014-15', '2015-16']
plot_histograms_for_selected_seasons(df, seasons)
seasons = ['2015-16', '2016-17']
plot_histograms_for_selected_seasons(df, seasons)

# %%
def calculate_statistics(laliga_data, start_year, end_year):
    seasons = [f'{year}-{str(year+1)[-2:]}' for year in range(start_year, end_year+1)]
    statistics = []
    
    for season in seasons:
        season_data = laliga_data[laliga_data['season'] == season]['points']
        mean = season_data.mean()
        median = season_data.median()
        std_dev = season_data.std()
        statistics.append((season, mean, median, std_dev))
    stats_df = pd.DataFrame(statistics, columns=['Season', 'Mean', 'Median', 'Standard Deviation'])
    print(stats_df)
    return stats_df
stats_df = calculate_statistics(df, 2000, 2016)
# Out:
#      Season   Mean  Median  Standard Deviation
# 0   2000-01  52.05    47.5           12.500421
# 1   2001-02  51.95    51.0           10.630022
# 2   2002-03  51.75    48.5           12.752193
# 3   2003-04  52.25    51.0           12.502105
# 4   2004-05  52.00    50.5           14.360032
# 5   2005-06  51.75    49.0           14.671401
# 6   2006-07  52.10    49.5           13.466919
# 7   2007-08  52.65    50.5           14.246976
# 8   2008-09  52.85    46.5           14.517775
# 9   2009-10  52.25    45.5           18.597892
# 10  2010-11  53.05    46.5           16.769254
# 11  2011-12  52.30    48.0           16.742948
# 12  2012-13  52.80    46.5           17.748536
# 13  2013-14  52.70    46.5           18.287471
# 14  2014-15  52.45    49.0           20.813647
# 15  2015-16  52.40    44.5           18.103213
# 16  2016-17  52.55    50.0           20.625674

# %%
def plot_histograms_for_all_seasons(laliga_data, start_year, end_year):
    
    plt.figure(figsize=(18, 12))
    
    min_points = 0
    max_points = laliga_data['points'].max()
    bins = np.arange(min_points, max_points + 10, 10) 

    seasons = [f'{year}-{str(year+1)[-2:]}' for year in range(start_year, end_year+1)]
    
    for season in seasons:
        season_data = laliga_data[laliga_data['season'] == season]['points']
        plt.hist(season_data, bins=bins, alpha=0.5, label=f'{season}', edgecolor='black')

    plt.xlabel('Points')
    plt.ylabel('Number of Teams')
    plt.title('Histograms of Points for All Seasons (2000-2016)')
    #plt.xticks(bins)  
    plt.legend(loc='upper right', bbox_to_anchor=(1.1, 1))
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout() 
    plt.show()
plot_histograms_for_all_seasons(df, 2000, 2016)

# %%
def min_points(laliga_data,season):
    season_data = laliga_data[laliga_data['season'] == season]
    min_points = season_data['points'].min()
    team_with_min_points = season_data[season_data['points'] == min_points]['club'].values[0]
    return {'club': team_with_min_points, 'points': min_points}

# %%
def max_points(laliga_data,season):
    season_data = laliga_data[laliga_data['season'] == season]
    max_points = season_data['points'].max()
    team_with_max_points = season_data[season_data['points'] == max_points]['club'].values[0]
    return {'club': team_with_max_points, 'points': max_points}

# %% [markdown]
# برای تست کردن توابع خود می‌توانید از دو سلول زیر استفاده کنید

# %%
season = '1997-98'
max_points_1997_98 = max_points(df, season)
print(max_points_1997_98)
assert max_points(df,'1997-98') == {'club': 'Barcelona', 'points': 74}
# Out:
# {'club': 'Barcelona', 'points': 74}

# %%
assert max_points(df,'1997-98') == {'club': 'Barcelona', 'points': 74}

# %% [markdown]
# حال از شما می‌خواهیم تابعی بنویسید تا با گرفتن نام فصل جدول آن فصل را خروجی دهد.
# - دقت کنید تیم‌ها در جدول یک فصل باید به ترتیب امتیاز و سپس تفاضل گل مرتب شده باشند.
# - پس از نوشتن تابع با امضای (`signature`) زیر آن را در `functions.py` قرار دهید.
# - دقت کنید`DataFrame` لالیگا به عنوان آرگوما اول به تابع ورودی داده می‌شود.

# %%
import importlib
import functions
importlib.reload(functions)
get_season_table = functions.get_season_table
season = '1997-98'
sorted_season_data = get_season_table(df, season)
sorted_season_data
# Out:
#       season                 club  home_win  away_win  home_loss  away_loss  \
# 527  1997-98            Barcelona        14         9          4          6
# 526  1997-98        Athletic Club        12         5          2          5
# 525  1997-98        Real Sociedad        10         6          1          6
# 524  1997-98          Real Madrid        12         5          3          6
# 523  1997-98   Atletico de Madrid        11         5          2          8
# 522  1997-98             Mallorca        10         6          4          6
# 521  1997-98        Celta de Vigo        14         3          1         11
# 520  1997-98                Betis        11         6          4          9
# 519  1997-98             Valencia         9         7          5         10
# 518  1997-98             Espanyol         9         3          3          6
# 517  1997-98           Valladolid         7         6          5          9
# 516  1997-98            Deportivo         9         3          4          9
# 515  1997-98        Real Zaragoza         4         8          5          9
# 514  1997-98            Salamanca         9         3          5         12
# 513  1997-98  Racing de Santander         8         4          7         10
# 512  1997-98             Tenerife         8         3          3         12
# 511  1997-98           Compostela         8         3          5         11
# 510  1997-98          Real Oviedo         7         2          6         10
# 509  1997-98               Merida         8         1          4         13
# 508  1997-98    Sporting de Gijon         2         0         15         14
#
#      matches_won  matches_lost  matches_drawn  total_matches  points  \
# 527           23            10              5             38      74
# 526           17             7             14             38      65
# 525           16             7             15             38      63
# 524           17             9             12             38      63
# 523           16            10             12             38      60
# 522           16            10             12             38      60
# 521           17            12              9             38      60
# 520           17            13              8             38      59
# 519           16            15              7             38      55
# 518           12             9             17             38      53
# 517           13            14             11             38      50
# 516           12            13             13             38      49
# 515           12            14             12             38      48
# 514           12            17              9             38      45
# 513           12            17              9             38      45
# 512           11            15             12             38      45
# 511           11            16             11             38      44
# 510            9            16             13             38      40
# 509            9            17             12             38      39
# 508            2            29              7             38      13
#
#      home_goals  away_goals  goals_scored  goals_conceded  goal_difference
# 527          42          36            78              56               22
# 526          36          16            52              42               10
# 525          33          27            60              37               23
# 524          34          29            63              45               18
# 523          47          32            79              56               23
# 522          34          21            55              39               16
# 521          34          20            54              47                7
# 520          30          19            49              50               -1
# 519          32          26            58              52                6
# 518          25          19            44              31               13
# 517          22          14            36              47              -11
# 516          32          12            44              46               -2
# 515          23          22            45              53               -8
# 514          33          13            46              46                0
# 513          26          20            46              55               -9
# 512          29          15            44              57              -13
# 511          30          26            56              66              -10
# 510          19          17            36              51              -15
# 509          25           8            33              53              -20
# 508          15          16            31              80              -49

# %%
get_season_table(df,'2015-16')
# Out:
#       season                club  home_win  away_win  home_loss  away_loss  \
# 887  2015-16           Barcelona        16        13          2          3
# 886  2015-16         Real Madrid        16        12          2          2
# 885  2015-16  Atletico de Madrid        15        13          1          5
# 884  2015-16          Villarreal        12         6          3          7
# 883  2015-16       Athletic Club        11         7          4          8
# 882  2015-16       Celta de Vigo         9         8          4          8
# 881  2015-16             Sevilla        14         0          4         10
# 880  2015-16              Malaga         8         4          5          9
# 879  2015-16       Real Sociedad         7         6          7          9
# 878  2015-16               Betis         6         5          7          8
# 877  2015-16            Valencia         6         5          6         10
# 876  2015-16          Las Palmas         8         4          6         12
# 875  2015-16               Eibar         8         3          6         11
# 874  2015-16            Espanyol         9         3          5         14
# 873  2015-16           Deportivo         4         4          7          5
# 872  2015-16   Sporting de Gijon         7         3          8         11
# 871  2015-16             Granada         6         4          8         11
# 870  2015-16      Rayo Vallecano         8         1          7         11
# 869  2015-16              Getafe         6         3          6         14
# 868  2015-16             Levante         7         1          7         15
#
#      matches_won  matches_lost  matches_drawn  total_matches  points  \
# 887           29             5              4             38      91
# 886           28             4              6             38      90
# 885           28             6              4             38      88
# 884           18            10             10             38      64
# 883           18            12              8             38      62
# 882           17            12              9             38      60
# 881           14            14             10             38      52
# 880           12            14             12             38      48
# 879           13            16              9             38      48
# 878           11            15             12             38      45
# 877           11            16             11             38      44
# 876           12            18              8             38      44
# 875           11            17             10             38      43
# 874           12            19              7             38      43
# 873            8            12             18             38      42
# 872           10            19              9             38      39
# 871           10            19              9             38      39
# 870            9            18             11             38      38
# 869            9            20              9             38      36
# 868            8            22              8             38      32
#
#      home_goals  away_goals  goals_scored  goals_conceded  goal_difference
# 887          67          45           112              29               83
# 886          70          40           110              34               76
# 885          33          30            63              18               45
# 884          26          18            44              35                9
# 883          35          23            58              45               13
# 882          29          22            51              59               -8
# 881          38          13            51              50                1
# 880          26          12            38              35                3
# 879          22          23            45              48               -3
# 878          17          17            34              52              -18
# 877          25          21            46              48               -2
# 876          25          20            45              53               -8
# 875          26          23            49              61              -12
# 874          22          18            40              74              -34
# 873          25          20            45              61              -16
# 872          28          12            40              62              -22
# 871          26          20            46              69              -23
# 870          29          23            52              73              -21
# 869          23          14            37              67              -30
# 868          23          14            37              70              -33

# %% [markdown]
# پرسشی وجود دارد که ایا در همه دوره‌های لالیگا تعداد یکسانی تیم حضور داشته‌اند؟
# .جواب را برای ۵ سال اولی که در داده‌ی ما وجود دارد می‌توانید در زیر مشاهده کنید

# %%
consistent_seasons = find_consistent_team_seasons(df)
pd.DataFrame.from_dict(consistent_seasons)
# Out:
#          club
# season
# 1972-73    18
# 1973-74    18
# 1974-75    18
# 1975-76    18
# 1976-77    18
# 1977-78    18
# 1978-79    18
# 1979-80    18
# 1980-81    18
# 1981-82    18
# 1982-83    18
# 1983-84    18
# 1984-85    18
# 1985-86    18
# 1986-87    18
# 1988-89    20
# 1989-90    20
# 1990-91    20
# 1991-92    20
# 1992-93    20
# 1993-94    20
# 1994-95    20
# 1996-97    22
# 1998-99    20
# 1999-00    20
# 2000-01    20
# 2001-02    20
# 2002-03    20
# 2003-04    20
# 2004-05    20
# 2005-06    20
# 2006-07    20
# 2007-08    20
# 2008-09    20
# 2009-10    20
# 2010-11    20
# 2011-12    20
# 2012-13    20
# 2013-14    20
# 2014-15    20
# 2015-16    20
# 2016-17    20

# %% [markdown]
# حال می‌خواهیم درباره قهرمان فصل‌های مختلف لالیگا اطلاعاتی بدست آوریم.برای همین باید ابتدا قهرمان هر فصل را مشخص کنیم.
#
# می‌توانید در جدول زیر قهرمان ۵ فصل اخیر لالیگا را ببینید.
#
# - دقت کنید در جدول زیر ویژگی `season` به عنوان `index` تنظیم شده

# %%
pd.DataFrame.from_dict({'club': {'2012-13': 'Barcelona',
  '2013-14': 'Atletico de Madrid',
  '2014-15': 'Barcelona',
  '2015-16': 'Barcelona',
  '2016-17': 'Real Madrid'}})
# Out:
#                        club
# 2012-13           Barcelona
# 2013-14  Atletico de Madrid
# 2014-15           Barcelona
# 2015-16           Barcelona
# 2016-17         Real Madrid

# %% [markdown]
# حال این جدول را برای همه فصل‌های موجود در داد تکمیل کنید و در فایل `champions.csv` ذخیره کنید.
# - دقت کنید که جدولی که ذحیره می‌کنید قالب یکسانی با جدول نمونه ارائه شده در بالا داشته باشد.

# %%
def find_champion(laliga_data, season):
    sorted_season_data = get_season_table(df, season)
    season_champion = sorted_season_data['club'].values[0]
    return season_champion

seasons = df['season'].unique()
champion_dict = {}
for season in seasons:
    champion_dict[season] = find_champion(df, season)

champion_df = pd.DataFrame(list(champion_dict.items()), columns=['season', 'club'])
champion_df.set_index('season', inplace=True)
pd.DataFrame.from_dict(champion_df)
# Out:
#                        club
# season
# 1970-71           Barcelona
# 1971-72         Real Madrid
# 1972-73  Atletico de Madrid
# 1973-74           Barcelona
# 1974-75         Real Madrid
# 1975-76         Real Madrid
# 1976-77  Atletico de Madrid
# 1977-78         Real Madrid
# 1978-79         Real Madrid
# 1979-80         Real Madrid
# 1980-81         Real Madrid
# 1981-82       Real Sociedad
# 1982-83       Athletic Club
# 1983-84         Real Madrid
# 1984-85           Barcelona
# 1985-86         Real Madrid
# 1986-87         Real Madrid
# 1987-88         Real Madrid
# 1988-89         Real Madrid
# 1989-90         Real Madrid
# 1990-91           Barcelona
# 1991-92           Barcelona
# 1992-93           Barcelona
# 1993-94           Barcelona
# 1994-95         Real Madrid
# 1995-96  Atletico de Madrid
# 1996-97         Real Madrid
# 1997-98           Barcelona
# 1998-99           Barcelona
# 1999-00           Deportivo
# 2000-01         Real Madrid
# 2001-02            Valencia
# 2002-03         Real Madrid
# 2003-04            Valencia
# 2004-05           Barcelona
# 2005-06           Barcelona
# 2006-07           Barcelona
# 2007-08         Real Madrid
# 2008-09           Barcelona
# 2009-10           Barcelona
# 2010-11           Barcelona
# 2011-12         Real Madrid
# 2012-13           Barcelona
# 2013-14  Atletico de Madrid
# 2014-15           Barcelona
# 2015-16           Barcelona
# 2016-17         Real Madrid

# %%
champion_df.to_csv('champions.csv')
loaded_df = pd.read_csv('champions.csv', index_col='season')
pd.DataFrame.from_dict(loaded_df)
# Out:
#                        club
# season
# 1970-71           Barcelona
# 1971-72         Real Madrid
# 1972-73  Atletico de Madrid
# 1973-74           Barcelona
# 1974-75         Real Madrid
# 1975-76         Real Madrid
# 1976-77  Atletico de Madrid
# 1977-78         Real Madrid
# 1978-79         Real Madrid
# 1979-80         Real Madrid
# 1980-81         Real Madrid
# 1981-82       Real Sociedad
# 1982-83       Athletic Club
# 1983-84         Real Madrid
# 1984-85           Barcelona
# 1985-86         Real Madrid
# 1986-87         Real Madrid
# 1987-88         Real Madrid
# 1988-89         Real Madrid
# 1989-90         Real Madrid
# 1990-91           Barcelona
# 1991-92           Barcelona
# 1992-93           Barcelona
# 1993-94           Barcelona
# 1994-95         Real Madrid
# 1995-96  Atletico de Madrid
# 1996-97         Real Madrid
# 1997-98           Barcelona
# 1998-99           Barcelona
# 1999-00           Deportivo
# 2000-01         Real Madrid
# 2001-02            Valencia
# 2002-03         Real Madrid
# 2003-04            Valencia
# 2004-05           Barcelona
# 2005-06           Barcelona
# 2006-07           Barcelona
# 2007-08         Real Madrid
# 2008-09           Barcelona
# 2009-10           Barcelona
# 2010-11           Barcelona
# 2011-12         Real Madrid
# 2012-13           Barcelona
# 2013-14  Atletico de Madrid
# 2014-15           Barcelona
# 2015-16           Barcelona
# 2016-17         Real Madrid

# %% [markdown]
# حال بر اساس جدول تکمیل شده در بخش قبلی، تعداد قهرمانی‌های هر تیم را بدست آورید و در متغیر `championship_count` قرار دهید.

# %%
clubs = df['club'].unique()
champions = loaded_df['club']
championship_count = {}
championCount = 0
for club in clubs:
    championCount = 0
    for champion in champions:
        if club == champion:
            championCount += 1
    championship_count[club] = championCount   
championship_count_df = pd.DataFrame(list(championship_count.items()), columns=['club', 'count'])
championship_count_df.set_index('club', inplace=True)
sorted_championship_count_df = championship_count_df.sort_values(by='count', ascending=False)
pd.DataFrame.from_dict(sorted_championship_count_df)
# Out:
#                         count
# club
# Real Madrid                20
# Barcelona                  18
# Atletico de Madrid          4
# Valencia                    2
# Athletic Club               1
# Deportivo                   1
# Real Sociedad               1
# Lleida                      0
# Villarreal                  0
# Compostela                  0
# Albacete                    0
# Merida                      0
# Real Burgos                 0
# Tenerife                    0
# Logrones                    0
# Mallorca                    0
# Extremadura                 0
# Real Zaragoza               0
# Alaves                      0
# Valladolid                  0
# Numancia                    0
# Malaga                      0
# Levante                     0
# Getafe                      0
# Gimnastic de Tarragona      0
# Almeria                     0
# Xerez                       0
# Eibar                       0
# Osasuna                     0
# Cadiz                       0
# AD Almeria                  0
# Recreativo de Huelva        0
# Las Palmas                  0
# Sabadell                    0
# Espanyol                    0
# Sporting de Gijon           0
# CD Malaga                   0
# Granada                     0
# Sevilla                     0
# Celta de Vigo               0
# Cordoba                     0
# Betis                       0
# Burgos                      0
# Real Oviedo                 0
# Castellon                   0
# Racing de Santander         0
# Murcia                      0
# Salamanca                   0
# Hercules                    0
# Elche                       0
# Rayo Vallecano              0
# Leganes                     0

# %% [markdown]
# حال با استفاده‌از کد زیر و نتیجه‌ی بخش قبل می‌توانید نمودار تعداد قهرمانی‌های هر تیم را ببینید.

# %% [markdown]
# می‌بینید که فقط ۷ تیم تا به حال قهرمان لالیگا شده‌اند!

# %%
pd.DataFrame(championship_count_df).rename(columns={'club':'count'}).to_csv('championship_count.csv')
plt.figure(figsize=(18, 12))
plt.title('Number of Championships Won for each Team')
plt.bar(championship_count_df.index, championship_count_df['count'])

plt.ylabel('Number of Championships Won')
plt.xticks(rotation = 75)
plt.show()

# %% [markdown]
# می‌توانید
# پس از ذخیره کردن نوت‌بوک،
# سلول زیر را اجرا کنید تا فایل های csv  را به همراه این نوت‌بوک زیپ کند.

# %%
import zipfile
import os


def compress(file_names):
    print("File Paths:")
    print(file_names)

    # Select the compression mode ZIP_DEFLATED for compression
    # or zipfile.ZIP_STORED to just store the file
    compression = zipfile.ZIP_DEFLATED

    # create the zip file first parameter path/name, second mode
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            # Add file to the zip file
            # first parameter file to zip, second filename in zip
            zf.write('./' + file_name, file_name, compress_type=compression)


file_names = [
    file for file in os.listdir()
    if (file.endswith('csv') or file.endswith('ipynb'))
    and file != 'LaLiga_dataset.csv'
]

compress(file_names)
# Out:
# File Paths:
# ['championship_count.csv', 'champions.csv', 'Lab_HW1.ipynb']
